# %%
import vtuIO
import matplotlib.pyplot as plt
import os

# %%
pvdfile = vtuIO.PVDIO("./_out/uplift.pvd", dim=3, interpolation_backend="scipy")
time = pvdfile.timesteps

points = {"pt0": (5, 6,0), "pt1": (5, 6,-30),"pt2": (5, 6,-50)}

# %% [markdown]
# Here we plot the time series.

# %%
displacement_linear = pvdfile.read_time_series("displacement", points)
#displacement_nearest = pvdfile.read_time_series("displacement", points, interpolation_method="nearest")

# %% [markdown]
# Here we plot the graphs.

# %%
plt.plot(time, displacement_linear["pt0"][:,2], "g-", label="$u_{z(" + str(points["pt0"][2]) + "m)}$")
plt.plot(time, displacement_linear["pt1"][:,2], "r-", label="$u_{z(" + str(points["pt1"][2]) + "m)}$")
plt.plot(time, displacement_linear["pt2"][:,2], "m-", label="$u_{z(" + str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Displacement (m)")
#plt.xscale('log')
# Out:
# Text(0, 0.5, 'Displacement (m)')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
relative_pt0_displacement =displacement_linear["pt0"][1:, 2]-displacement_linear["pt0"][:-1, 2]
plt.plot(time[1:], relative_pt0_displacement , "g-",  label='$\Delta$$u$$_z$$_{('+ str(points["pt0"][2])+ 'm)}$')

relative_pt1_displacement =displacement_linear["pt1"][1:, 2]-displacement_linear["pt1"][:-1, 2]
plt.plot(time[1:], relative_pt1_displacement , "r-",  label='$\Delta$$u$$_z$$_{('+ str(points["pt1"][2])+ 'm)}$')

relative_pt2_displacement = displacement_linear["pt2"][1:, 2]-displacement_linear["pt2"][:-1, 2]
plt.plot(time[1:], relative_pt2_displacement , "m-", label='$\Delta$$u$$_z$$_{('+ str(points["pt2"][2])+ 'm)}$')


plt.legend()
plt.xlabel("Timestep")
plt.ylabel("$\Delta$u$_{y}$" + " (m)")
# Out:
# Text(0, 0.5, '$\\Delta$u$_{y}$ (m)')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
GWT = -50 + time * 1

plt.plot(GWT, displacement_linear["pt0"][:, 2], "g-",  label="$u_{z(" + str(points["pt0"][2]) + "m)}$")
plt.plot(GWT, displacement_linear["pt1"][:, 2], "r-", label="$u_{z(" + str(points["pt1"][2]) + "m)}$")
plt.plot(GWT, displacement_linear["pt2"][:, 2], "m-", label="$u_{z(" + str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Location of Ground water table (m)")
plt.ylabel("Displacement (m)")
last_data= displacement_linear["pt0"][-1, 2]
last_data_3decimal= "%.3f" % round(last_data, 3)
plt.annotate(str(last_data_3decimal),(-10, last_data))
# Out:
# Text(-10, 0.6099439788696187, '0.610')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
stress = pvdfile.read_time_series("sigma", points, interpolation_method="linear")
plt.plot(time, -stress["pt0"][:, 2], "g-",  label="$\sigma\'_{zz}$$_{("+ str(points["pt2"][2])+ "m)}$")
plt.plot(time, -stress["pt1"][:, 2], "r-", label="$\sigma\'_{zz}$$_{("+ str(points["pt2"][2])+ "m)}$")
plt.plot(time, -stress["pt2"][:, 2], "m-", label="$\sigma\'_{zz}$$_{("+ str(points["pt2"][2])+ "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("$\sigma\'_{yy}$" + " (Pa)")
# Out:
# Text(0, 0.5, "$\\sigma'_{yy}$ (Pa)")

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
stress = pvdfile.read_time_series("sigma", points, interpolation_method="linear")

relative_pt0_stress = stress["pt0"][1:, 2]-stress["pt0"][:-1, 2]
plt.plot(time[:-1], relative_pt0_stress, "g-",  label="$\Delta\sigma\'_{zz}$$_{("+ str(points["pt0"][2])+ "m)}$")

relative_pt1_stress = stress["pt1"][1:, 2]-stress["pt1"][:-1, 2]
plt.plot(time[:-1], relative_pt1_stress, "r-",  label="$\Delta\sigma\'_{zz}$$_{("+ str(points["pt1"][2])+ "m)}$")

relative_pt2_stress = stress["pt2"][1:, 2]-stress["pt2"][:-1, 2]
plt.plot(time[:-1], relative_pt2_stress, "m-", label="$\Delta\sigma\'_{zz}$$_{("+ str(points["pt2"][2])+ "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("$\Delta\sigma\'_{zz}$" + " (Pa)")
# Out:
# Text(0, 0.5, "$\\Delta\\sigma'_{zz}$ (Pa)")

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
epsilon = pvdfile.read_time_series("epsilon", points, interpolation_method="linear")
plt.plot(time, epsilon ["pt0"][:, 2], "g-", label="$\epsilon_{z("+ str(points["pt0"][2]) + "m)}$")
plt.plot(time, epsilon ["pt1"][:, 2], "r-", label="$\epsilon_{z("+ str(points["pt1"][2]) + "m)}$")
plt.plot(time, epsilon ["pt2"][:, 2], "m-", label="$\epsilon_{z("+ str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Epsilon")
# Out:
# Text(0, 0.5, 'Epsilon')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
relative_pt0_epsilon = epsilon ["pt0"][1:, 2] - epsilon ["pt0"][:-1, 2]
relative_pt1_epsilon = epsilon ["pt1"][1:, 2] - epsilon ["pt1"][:-1, 2]
relative_pt2_epsilon = epsilon ["pt2"][1:, 2] - epsilon ["pt2"][:-1, 2]


plt.plot(time[:-1], relative_pt0_epsilon, "g-", label="$\Delta\epsilon_{z("+ str(points["pt0"][2]) + "m)}$")
plt.plot(time[:-1], relative_pt1_epsilon, "r-", label="$\Delta\epsilon_{z("+ str(points["pt1"][2]) + "m)}$")
plt.plot(time[:-1], relative_pt2_epsilon, "m-", label="$\Delta\epsilon_{z("+ str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Change in Epsilon")
# Out:
# Text(0, 0.5, 'Change in Epsilon')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
pore_pressure = pvdfile.read_time_series("pressure", points, interpolation_method="linear")
plt.plot(time, pore_pressure ["pt0"], "g-", label="$p_{z("+ str(points["pt0"][2]) + "m)}$")
plt.plot(time, pore_pressure ["pt1"], "r-", label="$p_{z(" + str(points["pt1"][2]) + "m)}$")
plt.plot(time, pore_pressure ["pt2"], "m-", label="$p_{z("+ str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Pore pressure (Pa)")
# Out:
# Text(0, 0.5, 'Pore pressure (Pa)')

# %%
relative_pt0_pore_pressure = pore_pressure ["pt0"][1:] - pore_pressure ["pt0"][:-1]
relative_pt1_pore_pressure = pore_pressure ["pt1"][1:] - pore_pressure ["pt1"][:-1]
relative_pt2_pore_pressure = pore_pressure ["pt2"][1:] - pore_pressure ["pt2"][:-1]

plt.plot(time[:-1], relative_pt0_pore_pressure , "g-", label="$\Delta p_{("+ str(points["pt0"][2]) + "m)}$")
plt.plot(time[:-1], relative_pt1_pore_pressure , "r-", label="$\Delta p_{("+ str(points["pt1"][2]) + "m)}$")
plt.plot(time[:-1], relative_pt2_pore_pressure , "m-", label="$\Delta p_{("+ str(points["pt2"][2]) + "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("Change in pore pressure (Pa)")
# Out:
# Text(0, 0.5, 'Change in pore pressure (Pa)')

# %%
totalstress_pt0 = -stress["pt0"][:, 1] + pore_pressure["pt0"]
totalstress_pt1 = -stress["pt1"][:, 1] + pore_pressure["pt1"]
totalstress_pt2 = -stress["pt2"][:, 1] + pore_pressure["pt2"]

#plt.plot(time, totalstress_pt0 , "g-", label="$totalstress_{zz("+ str(points["pt0"][1]) + "m)}$")
plt.plot(time, totalstress_pt1 , "r-", label='$\Delta\sigma$$_{zz}$$_{('+ str(points["pt1"][2])+ 'm)}$')
plt.plot(time, totalstress_pt2 , "m-", label='$\Delta\sigma$$_{zz}$$_{('+ str(points["pt2"][2])+ 'm)}$')

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("$\sigma$$_{zz}$" + ' (Pa)')
# Out:
# Text(0, 0.5, '$\\sigma$$_{zz}$ (Pa)')

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig: "None | int | str | Figure | Literal['all']" = None) -> 'None'>

# %%
relative_pt0_totalstress = totalstress_pt0[1:] - totalstress_pt0[:-1]
relative_pt1_totalstress = totalstress_pt1[1:] - totalstress_pt1[:-1]
relative_pt2_totalstress = totalstress_pt2[1:] - totalstress_pt2[:-1]

plt.plot(time[:-1], relative_pt0_totalstress , "g-", label="$\Delta\sigma_{zz}$$_{("+ str(points["pt0"][2])+ "m)}$")
plt.plot(time[:-1], relative_pt1_totalstress , "r-", label="$\Delta\sigma_{zz}$$_{("+ str(points["pt1"][2])+ "m)}$")
plt.plot(time[:-1], relative_pt2_totalstress , "m-", label="$\Delta\sigma_{zz}$$_{("+ str(points["pt2"][2])+ "m)}$")

plt.legend()
plt.xlabel("Timestep")
plt.ylabel("$\Delta$$\sigma$$_{zz}$")
# Out:
# Text(0, 0.5, '$\\Delta$$\\sigma$$_{zz}$')
