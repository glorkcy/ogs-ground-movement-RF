# %%
# Create output path if it doesn't exist yet
import os
from pathlib import Path

out_dir = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out"))
#if not out_dir.exists():
#    out_dir.mkdir(parents=True)

# %%
os.chdir(out_dir)

# %%
print (os.getcwd())
# Out:
# c:\Users\glori\Documents\tasks\ogs_exercise\3D\_out

# %%
# Import OGS class
from ogs6py.ogs import OGS


# Initiate an OGS-object
# Pass it the project file and set an output file 
model = OGS(INPUT_FILE = "input_3D.prj", PROJECT_FILE="input_3D.prj")

# Run OGS
model.run_model(logfile="out_3D.txt")
# Out:
# OGS finished with project file input_3D.prj.
# Execution took 981.5074009895325 s
# Project file written to output.

# %%
os.chdir('..')
print (os.getcwd())
# Out:
# c:\Users\glori\Documents\tasks\ogs_exercise\3D
